# %%
import matplotlib.pyplot as plt 
from astropy.io import fits 
import numpy as np

# %%
obs = fits.open("/home/milic/data/scratch/mihi_data.fits")[0].data
obs.shape
# Out:
# (146, 160, 4, 638)

# %%
obs = obs[15:-15, 15:-15, 0, 45:525]
obs.shape
# Out:
# (116, 130, 480)

# %%
fit = fits.open("test_inverted.fits")[1].data
fit.shape
# Out:
# (116, 130, 480)

# %%
model = fits.open("test_inverted.fits")[0].data
model.shape
# Out:
# (116, 130, 11)

# %%
i = 66
j = 71
plt.figure(figsize=[8,5])
plt.plot(obs[i,j])
plt.plot(fit[i,j])
